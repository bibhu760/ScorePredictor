# %%
import pandas as pd
import numpy as np
import os
from yaml import safe_load
from tqdm import tqdm
import pickle

# %%
# pip install pyyaml

# %%
filenames=[]
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
final_df=pd.DataFrame()
counter=1
for file in tqdm(filenames):
    with open(file,'r') as f:
        df=pd.json_normalize(safe_load(f))
        df['match_id']=counter
        final_df=pd.concat([final_df,df])
        counter+=1
# Out:
# 100%|█████████▉| 7469/7470 [1:01:13<00:00,  2.03it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[41], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file,'r') as f:
# ----> 5         df=pd.json_normalize(safe_load(f))
#       6         df['match_id']=counter
#       7         final_df=pd.concat([final_df,df])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
# ...

# %%
pickle.dump(final_df,open('final_df.pkl','wb'))

# %%
backup=final_df.copy()

# %%
backup.to_csv('backup.csv')

# %%
# final_df=pd.read_csv('backup.csv')

# %%
final_df.shape
# Out:
# (7469, 45)

# %%
final_df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'South Africa', 'dec...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Pakistan', 'declare...                0.9
#
#   meta.created  meta.revision info.city  \
# 0   2016-11-09              2     Perth
# 0   2016-11-16              2    Hobart
# 0   2016-12-05              1       NaN
# 0   2016-12-21              1  Brisbane
# 0   2016-12-31              1       NaN
#
#                                           info.dates info.gender  \
# 0  [2016-11-03, 2016-11-04, 2016-11-05, 2016-11-0...        male
# 0   [2016-11-12, 2016-11-13, 2016-11-14, 2016-11-15]        male
# 0   [2016-11-24, 2016-11-25, 2016-11-26, 2016-11-27]        male
# ...

# %%
# droping non relevent features
final_df=final_df.drop(columns=
    ['meta.data_version', 
    'meta.created',
    'meta.revision',
     'info.bowl_out', 
     'info.outcome.bowl_out',
     'info.outcome.result',
       'info.outcome.method', 
     'info.neutral_venue',
     'info.player_of_match',
    'info.supersubs.Melbourne Renegades',
       'info.supersubs.Adelaide Strikers', 'info.supersubs.Hobart Hurricanes',
       'info.supersubs.Melbourne Stars', 'info.supersubs.Australia',
       'info.supersubs.England', 'info.supersubs.Africa XI',
       'info.supersubs.Asia XI', 'info.supersubs.Zimbabwe',
       'info.supersubs.Sri Lanka', 'info.supersubs.Bangladesh',
       'info.supersubs.New Zealand', 'info.supersubs.India',
       'info.supersubs.ICC World XI', 'info.supersubs.South Africa',
       'info.supersubs.Pakistan', 'info.supersubs.West Indies'
      ]
)

# %%
final_df.columns
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.by.runs', 'info.outcome.winner', 'info.player_of_match',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.umpires',
#        'info.venue', 'match_id', 'info.outcome.by.innings',
#        'info.outcome.by.wickets', 'info.overs', 'info.competition',
#        'info.outcome.eliminator', 'info.match_type_number'],
#       dtype='object')

# %%
#extracting only T20 data
final_df_T20=final_df[final_df['info.match_type']=='T20']

# %%
final_df_T20.shape
# Out:
# (4082, 20)

# %%
final_df_T20.isnull().sum()
# Out:
# innings                       0
# info.city                   412
# info.dates                    0
# info.gender                   0
# info.match_type               0
# info.outcome.by.runs       2151
# info.outcome.winner         139
# info.player_of_match        220
# info.teams                    0
# info.toss.decision            0
# info.toss.winner              0
# info.umpires                 22
# info.venue                    0
# match_id                      0
# info.outcome.by.innings    4082
# info.outcome.by.wickets    2071
# info.overs                    0
# info.competition           1432
# info.outcome.eliminator    4038
# info.match_type_number     3383
# dtype: int64

# %%
final_df_T20=final_df_T20.drop(columns=['info.outcome.eliminator','info.outcome.by.innings'])

# %%
final_df_T20['info.gender'].value_counts()
# Out:
# info.gender
# male      3352
# female     730
# Name: count, dtype: int64

# %%
final_df_T20_man=final_df_T20[final_df_T20['info.gender']=='male']

# %%
final_df_T20_man['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    3352
# Name: count, dtype: int64

# %%
final_df_T20_man['info.overs'].value_counts()
# Out:
# info.overs
# 20.0    3349
# 50.0       3
# Name: count, dtype: int64

# %%
final_df_T20_man=final_df_T20_man[final_df_T20_man['info.overs']==20.0]

# %%
final_df_T20_man=final_df_T20_man.drop(columns=['info.overs','info.match_type'])

# %%
final_df_T20_man.head(2)
# Out:
#                                              innings info.city    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...       NaN  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  Victoria  [2017-02-19]
#
#   info.gender  info.outcome.by.runs info.outcome.winner info.player_of_match  \
# 0        male                   NaN           Sri Lanka      [DAS Gunaratne]
# 0        male                   NaN           Sri Lanka      [DAS Gunaratne]
#
#                info.teams info.toss.decision info.toss.winner  \
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
#
#              info.umpires                      info.venue  match_id  \
# 0  [MD Martell, P Wilson]        Melbourne Cricket Ground        12
# 0   [SD Fry, SJ Nogajski]  Simonds Stadium, South Geelong        13
#
#    info.outcome.by.wickets info.competition  info.match_type_number
# ...

# %%
#checking the innings wise data
final_df_T20_man['innings'].iloc[1][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {0.5: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'extras': {'legbyes': 1},
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.1: {'batsman': 'M Klinger',
# ...

# %%
wicket=[]
for ball in final_df_T20_man['innings'].iloc[1][0]['1st innings']['deliveries']:
    for key in ball.keys():
        # print(ball[key].keys())
        if 'wicket' in ball[key].keys():
            print(ball[key]['wicket']['player_out'])
        #     # print(wicket)
        # print(key)
# Out:
# AJ Finch
# BR Dunk
# M Klinger
# TM Head
# AJ Turner
# JP Faulkner
# TD Paine
# PJ Cummins
# AJ Tye
# JA Richardson

# %%
delivery_df=pd.DataFrame()

# %%
#extracting the ball by ball data
count=1
delivery_df=pd.DataFrame()
for index,row in final_df_T20_man.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match=[]
    batsman=[]
    bowler=[]
    runs=[]
    player_of_dismissed=[]
    teams=[]
    batting_team=[]
    match_id=[]
    city=[]
    venue=[]
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            # try:
            #     player_of_dismissed.append(ball[key]['wicket']['players_out'])
            # except:
            #     player_of_dismissed.append('0')
            if 'wicket' in ball[key].keys():
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
                # print(ball[key]['wicket']['player_out'])
            else:
                # print('none')
                player_of_dismissed.append('0')
                
                                           
    loop_df=pd.DataFrame({
        'match_id':match_id,
        'teams':teams,
        'batting_team':batting_team,
        'ball':ball_of_match,
        'batsman':batsman,
        'bowler':bowler,
        'runs':runs,
        'player_dismissed':player_of_dismissed,
        'city':city,
        'venue':venue
    })
    delivery_df=pd.concat([delivery_df,loop_df])

# %%
delivery_df.head()
# Out:
#    match_id                   teams batting_team  ball    batsman      bowler  \
# 0         2  [Australia, Sri Lanka]    Australia   0.1   AJ Finch  SL Malinga
# 1         2  [Australia, Sri Lanka]    Australia   0.2   AJ Finch  SL Malinga
# 2         2  [Australia, Sri Lanka]    Australia   0.3   AJ Finch  SL Malinga
# 3         2  [Australia, Sri Lanka]    Australia   0.4  M Klinger  SL Malinga
# 4         2  [Australia, Sri Lanka]    Australia   0.5  M Klinger  SL Malinga
#
#    runs player_dismissed city                     venue
# 0     0                0  NaN  Melbourne Cricket Ground
# 1     0                0  NaN  Melbourne Cricket Ground
# 2     1                0  NaN  Melbourne Cricket Ground
# 3     2                0  NaN  Melbourne Cricket Ground
# 4     0                0  NaN  Melbourne Cricket Ground

# %%
# find bowling team
def bowl(row):
    for team in row['teams']:
        if team !=row['batting_team']:
            return team

# %%
delivery_df['bowling_team']=delivery_df.apply(bowl,axis=1)

# %%
delivery_df.head()
# Out:
#    match_id                   teams batting_team  ball    batsman      bowler  \
# 0         2  [Australia, Sri Lanka]    Australia   0.1   AJ Finch  SL Malinga
# 1         2  [Australia, Sri Lanka]    Australia   0.2   AJ Finch  SL Malinga
# 2         2  [Australia, Sri Lanka]    Australia   0.3   AJ Finch  SL Malinga
# 3         2  [Australia, Sri Lanka]    Australia   0.4  M Klinger  SL Malinga
# 4         2  [Australia, Sri Lanka]    Australia   0.5  M Klinger  SL Malinga
#
#    runs player_dismissed city                     venue bowling_team
# 0     0                0  NaN  Melbourne Cricket Ground    Sri Lanka
# 1     0                0  NaN  Melbourne Cricket Ground    Sri Lanka
# 2     1                0  NaN  Melbourne Cricket Ground    Sri Lanka
# 3     2                0  NaN  Melbourne Cricket Ground    Sri Lanka
# 4     0                0  NaN  Melbourne Cricket Ground    Sri Lanka

# %%
delivery_df['player_dismissed'].value_counts()
# Out:
# player_dismissed
# 0               383723
# RG Sharma          139
# BB McCullum        134
# KA Pollard         132
# AJ Finch           131
#                  ...
# A Gavde              1
# JM Anderson          1
# Imran Qayyum         1
# KO Otieno            1
# RD Gaikwad           1
# Name: count, Length: 2035, dtype: int64

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'St Lucia Zouks',
#        'Guyana Amazon Warriors', 'Trinbago Knight Riders',
#        'Jamaica Tallawahs', 'Barbados Tridents', 'Bangladesh',
#        'New Zealand', 'South Africa', 'Sydney Thunder', 'Brisbane Heat',
#        'Melbourne Renegades', 'Hobart Hurricanes', 'Perth Scorchers',
#        'Adelaide Strikers', 'Melbourne Stars', 'Sydney Sixers', 'England',
#        'West Indies', 'Ireland', 'Afghanistan', 'Pakistan', 'Yorkshire',
#        'Surrey', 'Lancashire', 'Hampshire', 'Gloucestershire',
#        'Worcestershire', 'Northamptonshire', 'Derbyshire',
#        'Nottinghamshire', 'Durham', 'Glamorgan', 'Essex', 'Kent',
#        'Warwickshire', 'Leicestershire', 'Somerset', 'Middlesex',
#        'Sussex', 'United Arab Emirates', 'Scotland', 'Oman',
#        'Peshawar Zalmi', 'Quetta Gladiators', 'Karachi Kings',
#        'Islamabad United', 'Lahore Qalandars', 'Sunrisers Hyderabad',
# ...

# %%
#considering only the majority cricket playing team
teams=[
    'Australia',
    'India',
    'New Zealand',
    'South Africa',
    'Bangladesh',
    'England',
    'West Indies', 
    'Ireland', 
    'Afghanistan', 
    'Pakistan', 
]

# %%
delivery_df=delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df=delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df.shape
# Out:
# (54402, 10)

# %%
output=delivery_df[['match_id', 'batting_team','bowling_team', 'ball', 'runs',
       'player_dismissed', 'city', 'venue']]

# %%
output
# Out:
#     match_id batting_team bowling_team  ball  runs player_dismissed    city  \
# 0         21   Bangladesh  New Zealand   0.1     0                0  Napier
# 1         21   Bangladesh  New Zealand   0.2     0                0  Napier
# 2         21   Bangladesh  New Zealand   0.3     0                0  Napier
# 3         21   Bangladesh  New Zealand   0.4     0                0  Napier
# 4         21   Bangladesh  New Zealand   0.5     1                0  Napier
# ..       ...          ...          ...   ...   ...              ...     ...
# 88      3278   Bangladesh        India  14.2     2                0  Mirpur
# 89      3278   Bangladesh        India  14.3     0                0  Mirpur
# 90      3278   Bangladesh        India  14.4     2                0  Mirpur
# 91      3278   Bangladesh        India  14.5     1                0  Mirpur
# 92      3278   Bangladesh        India  14.6     1                0  Mirpur
#
#                             venue
# ...

# %%
pickle.dump(output,open('output.pkl','wb'))
